# %%
name <- c ("Iran","USA","Turki","Russia","Pak")
pop <- c(12,34,54,34,56)
area <- c(312,115,297,123,200)
developed <- c(FALSE,TRUE,FALSE,TRUE,FALSE)
countries <- data.frame(name,pop,area,developed,stringsAsFactors = FALSE)

plot(countries$pop)
# Out:
# plot without title

# %%
plot(countries$pop,countries$area)
# Out:
# plot without title
